# %% [markdown]
# #Importing Libraries

# %% [markdown]
# > Do a check to gain more information about requests module: https://www.w3schools.com/python/module_requests.asp
#
# > Know More about Python List: https://www.w3schools.com/python/python_lists.asp, https://www.w3schools.com/python/python_lists_access.asp
#
#
#
#
# > If you want to know more about BeautifulSoup : https://beautiful-soup-4.readthedocs.io/en/latest/
#
# **Not possible to cover every concept today,but I can give you the basic understanding about it**: 🙂

# %% [markdown]
# ***You can always remove the '#' and run the following commands , also '#' is used to make a comment in python***

# %%
# Import necessary libraries
import requests
from bs4 import BeautifulSoup as bsp
import pandas as pd

# %%
# Send Request
requests.get('https://internshala.com/internships/','html.parser')
# Out:
# <Response [200]>

# %%
requests.get('https://internshala.com/internships/','html.parser').content
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml"\n      lang="en-US">\n\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=9" />\n    <meta charset="UTF-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0 user-scalable=0" />\n    <meta property="fb:app_id" content="702141670710132" />\n    <meta property="og:type" content="website" />\n        <meta property="og:image:width" content="1200" />\n    <meta property="og:image:height" content="630" />\n    <link rel="preload" href="https://internshala.com//static/images/home/sprites/img-assets.png" as="image"/>\n<link rel="preload" as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r767.png" media="(max-width: 767px)"/>\n<link rel="preload" as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r1920.png" media="(min-width: 767.1px)"/>    <meta name="twitter:site" content="@Internshala" />\n        <meta name="twitter:card" content="summary_large_image" />\n    \n    <meta name="twitter:creator" content="@internshala" />\n        <meta name="theme-color" content="#ffffff" />\n    <meta name="msapplication-navbutton-color" content="#ffffff" />\n    <meta name="format-detection" content="telephone=no" />\n\n        <link as="font" href="/static/fonts/Inter.woff2?v=3.11" type="font/woff2" crossorigin />\n    <link as="font" href="/static/fonts/internshala-icons.woff2?vw3rgh" type="font/woff2"  crossorigin />    <script src="/static/js/web_vitals/web-vitals.umd.js"></script>\n    <script src="/static/js/includes/common/libraries.2583691470.js" defer></script>\n       <link rel="stylesheet" href="https://internshala.com//static/cdn/4.4.1/css/bootstrap.min.css" />\n    \n    <link rel="icon" href="https://internshala.com//favicon.ico?v=5" />\n    <script nonce="j1W9kMFIoye51e71mY/rdA==">\n    window.onerror = function (error, url, line, col, fullError) {\n        error = fullError || error;\n        store_data(error, line);\n    };\n\n    function store_data(error, line) {\n        error = error.stack || error;\n        var url = window.location.href;\n        var browser = get_browser();\n        var browser_name = browser.name;\n        var browser_version = browser.version;\n        var browser_ua = browser.user_agent;\n        var message = "error=" + error + ". Line:" + line + "&browser=" + browser_name + "&version=" + browser_version + "&url=" + url + "&ua=" + browser_ua;\n        // var xhttp = new XMLHttpRequest();\n        // xhttp.onreadystatechange = function () {\n        //     if (this.readyState === 4 && this.status === 200) {\n\n        //     }\n        // };\n        // xhttp.open("POST", "/browser_error/insert_browser_logs", true);\n        // xhttp.setRequestHeader(\'X-Requested-With\', \'XMLHttpRequest\');\n        // xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");\n        // xhttp.send(message);\n    }\n\n    function get_browser() {\n        var ua = navigator.userAgent, tem, M = ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\\/))\\/?\\s*(\\d+)/i) || [];\n        if (/trident/i.test(M[1])) {\n            tem = /\\brv[ :]+(\\d+)/g.exec(ua) || [];\n            return {name: \'IE\', version: (tem[1] || \'\')};\n        }\n        if (M[1] === \'Chrome\') {\n            tem = ua.match(/\\bOPR|Edge\\/(\\d+)/)\n            if (tem != null) {\n                return {name: \'Opera\', version: tem[1]};\n            }\n        }\n        M = M[2] ? [M[1], M[2]] : [navigator.appName, navigator.appVersion, \'-?\'];\n        if ((tem = ua.match(/version\\/(\\d+)/i)) != null) {\n            M.splice(1, 1, tem[1]);\n        }\n        return {\n            name: M[0],\n            version: M[1],\n            user_agent: ua\n        };\n    }\n</script>\n    <script nonce="j1W9kMFIoye51e71mY/rdA==">\n    var os_type = "";\n    var browser_name = \'pytho ...

# %%
url='https://internshala.com/internships/'

# %% [markdown]
# # Getting Responses from the website

# %%
resp=requests.get(url,'html.parser')
print(resp.status_code)
# Out:
# 200

# %%
# filtrering Field
field="web-development"
print(field)
# Out:
# web-development

# %% [markdown]
# # URL Handling

# %%
# Create a modified URL for the specified field
modified_url=url+str(field)+'-internship/'
# Print the status of the new request
print(f"Status :{requests.get(modified_url)}")
print(modified_url)# Print the modified URL
# Out:
# Status :<Response [200]>
# https://internshala.com/internships/web-development-internship/

# %%
# Send a new request to the modified URL
resp_new=requests.get(modified_url)

# %%
# Parse the response content using BeautifulSoup
soup=bsp(resp_new.content,'html.parser')
#print(soup)

# %%
# type(soup)

# %%
# Find the total number of pages available
pages=int(soup.find('span',id='total_pages').text)
# print(pages)

# %%
# Generate a list of URLs for all pages
urlList = []
page = 1
while page <= pages:
  newUrl = modified_url+str(f"page-{page}/")
  urlList.append(newUrl)
  page +=1
# print(urlList) # Print the list of URLs

# %%
# Initialize a list to store the parsed content of each page
soup2 = []
for url in urlList:
  resp_new=requests.get(url)
  soup3=bsp(resp_new.content,'html.parser')
  soup2.append(soup3)
# print(len(soup2)) # Print the number of pages parsed

# %%
# print(soup.prettify())

# %% [markdown]
# # Scraping

# %%
# Initialize lists to store the internship details
name=[]
for soup in soup2:
  names=soup.find_all('div',class_='individual_internship_header')
  for i in names:
    name.append(i)
# print(len(name))
#print(name)

# %%
# print(type(name))
# profile=name.find_all('h3',class_='heading_4_5 profile')

# %%
# for i in name:
#   p=i.find('h3',class_='heading_4_5 profile')
  # print(p)
  # print(p.text)
  # print(p.text.strip())
  # break

# %%
# Extract and filter internship profiles
profile=[]
for i in name:
  p=i.find('h3',class_='heading_4_5 profile')
  # print(p)
  # print(p.text)
  # print(p.text.strip())
  a=p.text.strip()
  profile.append(a)
  #break
# print(len(profile))
print(f"All profiles available are : {profile}")
# Out:
# All profiles available are : ['Ruby Software Developer', 'Java Development', 'Backend Development', 'PHP Development', 'Web Development', 'Web Development', 'Node.js Development', 'Web Development', 'Reactjs Development', 'WordPress Development', 'WordPress Developer', 'Front End Development', 'Backend Development', 'Node.js Development', 'Python Development', 'Chrome Extension And Next.js Development', 'Python Developer With Good Hands On API Development, Flask, FastAPI.', 'Full Stack Development', 'PHP Development', 'Python Development', 'PHP Development (WordPress)', 'Front End Development', 'Flutter Development', 'WordPress Development', 'Reactjs Development', 'Python Development', 'WordPress Development', 'Web Development', 'Reactjs Development', 'WordPress Development', 'Frontend Developer Intern', 'WordPress, ReactJS, NoCode Platforms Design & Development', 'PHP Development', 'Flutter Development', 'Reactjs Development', 'Web Development', 'Front End Development', 'React/Node.js Web/UI Developer', 'Web Development', 'Front End Development', 'Core Backend Development', 'WordPress Development', 'WordPress Development', 'Web Development', 'Information Technology', 'Full Stack Development', 'Backend Development', 'PHP Development', 'Front End Development', 'Flutter Development', 'Asp.net Development', 'Full Stack Development', 'WordPress Development', 'Full Stack Web Development Mentor', 'Front End Developer - Intern', 'Web Development & E-Commerce Inventory Management', 'Flutter Development', 'PHP Backend Development', 'Front End Development', 'Web Designing', 'Full Stack Development', 'WordPress Development', 'Trainee Engineer', 'Full Stack Development', 'Python Development', 'WordPress Development', 'WordPress Development', 'Backend Development', 'WordPress Development', 'E Commerce Web App Development Using React JS And Node JS', 'WordPress Development', 'Flutter Development', 'WordPress Development', 'PHP Laravel', 'Backend Development', 'Python Development', 'React Native Developer', 'WordPress Development', 'Backend Development', 'Signal Processing For Advanced Antenna Systems', 'Flutter Development', 'Web Development', 'Full Stack Development', 'React Native', 'Systems Developer (MIS)', 'Flutter Developer', 'Web Development', 'Flutter Development', 'Full Stack Development', 'Web Development', 'Flutter - Social Chat Developer', 'Web Browser Game Development (Javascript)', 'Webflow', 'Backend Developer (NextJS And Typescript)', 'Wix Website Development', 'Python Tutor', 'WordPress Development', 'Python & Prompt Engineering', 'Blockchain Development', 'Web Development', 'PHP Development', 'NEXT.Js Developer', 'Front End Development', 'WordPress Development', 'WordPress Development', 'Front End Development', 'Full Stack Development', 'React Developer', 'Blockchain Development', 'Reactjs Development', 'Angular.js Development', 'Full Stack API Automation Engineer', 'MERN/Python Developer', 'Java Development', 'PHP Development', 'Full Stack Blockchain Developer', 'Front End Development', 'Full Stack Development', 'Flutter Development', 'Flutter Development', 'Front End Development', 'Front End Development', 'WordPress Development', 'Web Designer', 'Python Development', 'Flutter Development', 'Node.js Development', 'WordPress Development', 'Full Stack Development', 'Backend Development', 'Web Developer', 'Web Development', 'Blockchain Development', 'WordPress Development', 'Full Stack Development', 'Full Stack Development', 'Blockchain Development', 'Flutter Developer', 'Blockchain Development', 'Web Development', 'IT Content Creations', 'WordPress Development', 'React Native Developer', 'Technical Shopify Developer', 'Junior Python Developer', 'Web Development', 'Reactjs Development', 'Flutter Development', 'Flutter Development', 'Python Full Stack Development', 'Full Stack Development', 'Python Development', 'Flutter Development', 'Blockchain Development', 'Web Development', 'Web Development', 'Blockchain Development', 'W ...

# %%
# Extract company names
company=[]
for i in name:
  com=i.find('p').text.strip()
  #print(com)
  company.append(com)
# print(len(company))
print(company)
# Out:
# ['Peach', 'CODTECH IT SOLUTIONS PRIVATE LIMITED', 'Flint Merchandising LLP', 'Dakshith Technologies', 'MentorBoxx', 'T.I.M.E Education', 'Across The Globe (ATG)', 'Digimindss', 'Close Digit LLP', 'DiziGroww', 'The Learn Cloud', 'Worko.ai', 'Worko.ai', 'Wellfounded IT Solution Private Limited', 'Bamigos', 'Solocl', 'Arthalab Solutions', 'PiSence Technologies LLP', 'Bytive Technologies Private Limited', 'Indietoga', 'Chirpn IT Solutions', 'OCPL Tech (Opulentia Cresco Private Limited)', 'Coding Junior', 'EVKhoj', 'Across The Globe (ATG)', 'Warewe Consultancy Private Limited', 'Blackcoffer', 'Chatcells', 'IWebcode', 'Confluencr', 'Quantazone Software Private Limited', 'Polygon Pixels LLP', 'OyeLabs', 'OyeLabs', 'OyeLabs', 'Youth Ki Awaz Newspaper', 'DataChannel Technologies', 'Dendrite.ai', 'Vedlogy Learnings Private Limited', 'TRATA SOFTWARE', 'Weframe Tech', 'Cloudbloom', 'Grivaa Consultancy Services', 'Mechons Industries', 'Brain Wave AI Solutions', 'Anmol Industries Limited', 'Webknot Technologies Private Limited', 'Spirant Communication Pvt Ltd', 'Mugs', 'Idea Usher', 'WOODESY', 'Teevro', 'Bunny Bash Events & Rentals', 'DevTown', 'DevTown', 'Cycling Boutique Incorporation', 'Blackcoffer', 'Coding Junior', 'Allianz Exports', 'Stirring Minds', 'Labsmart Healthcare Technologies', 'Digipsum', 'Rizzle', 'Wizda', 'Comfit And Valves Private Limited', 'Funnels Traffic', 'Mantra Yoga And Meditation School', 'ValuQo Services Private Limited', 'Library Of The World', 'MyMegaminds', 'Bunny Bash Events & Rentals', 'Zarity Health', 'SUMDRAGROFOODS LLP', 'Across The Globe (ATG)', 'Alemeno', 'Bilateral Solutions Private Limited', 'Webknot Technologies Private Limited', 'Yellowfin Gears', 'ReachInbox.ai', 'Husoro Enterprises LLP', 'Wellmo Services OPC Private Limited', 'Myla Organics', 'Systemic Altruism', '1Millions Entrepreneurs International Forum', 'Prache Khade', 'Luneblaze', 'Webmobi', 'Ostello India Private Limited', 'Techvolt Software Private Limited', 'Techvolt Software Private Limited', 'Systemic Altruism', 'Systemic Altruism', 'Systemic Altruism', 'Quizzy', 'PatilKaki', 'Triluxo Technologies Private Limited', 'Constructive Solutions, Inc.', 'ODN Digital Services Private Limited', 'Buddha Education Association Incorporation', 'Buddha Education Association Incorporation', 'SmartCookie', 'Ayurveda House Private Limited', 'Medius Technologies Private Limited', 'Chimaya', 'Webalar', 'Medius Technologies Private Limited', 'EazyGrad', 'WiJungle - by HttpCart', 'Gateway Software Solutions', 'Webknot Technologies Private Limited', 'Gateway Software Solutions', 'Systemic Altruism', 'Systemic Altruism', 'Gateway Software Solutions', 'Onlighten Media', 'Systemic Altruism', 'Onlighten Media', 'Quantum IT Innovation', 'Quantum IT Innovation', 'Engaze', 'Quantum IT Innovation', 'Vigorous Healthtech Private Limited', 'Webcap Technology', 'Vestaso', 'AI Certs', 'AI Certs', 'AI Certs', 'AI Certs', 'Megaminds IT Services', 'OCPL Tech (Opulentia Cresco Private Limited)', 'Aadi Foundation', 'Indica', 'Reveation Labs', 'Bizwit Research & Consulting LLP', 'Alluvium IoT Solutions Private Limited', 'Interactive Digitalmedia (IDM) Private Limited', 'Reveation Labs', 'Mobitech Industries LLP', 'Sharcon Infrastructure Private Limited', 'Modgenics Technology Solutions Private Limited', 'BrandMBG', 'Heliverse', 'Tensorblue', 'Axe Consultancy And Security Services LLC', 'BinTech Group LLC', 'Delkon Technologies', 'Mavenpro Solutions', 'Zylife Smartcare Private Limited', 'Skygoal', 'Blackcoffer', 'Elearning Design Center LLC', 'Tensorblue', 'RevoltronX', 'Avaari', 'Avaari', 'Avaari', 'Avaari', 'Stories Arabia FZ', 'Infinite Creations Private Limited', 'Blazpay Labs Corp', 'Perky', 'OpenSense Labs Private Limited', 'Guruji Astro', 'Adisri Publications Private Limited', 'Gobananas', 'Auctopus Technologies Private Limited', 'Rancho Labs', 'Kudosware', 'Simple Enterprises', 'PlayTheory Labs', 'Salesqueen Software Solutions (Chennai, India)', 'Atelierish Media', 'Kavy ...

# %%
# Extract internship details
detail=[]
for soup in soup2:
  detailList=soup.find_all('div',class_='individual_internship_internship')
  for i in detailList:
    detail.append(i)
print(len(detail))  # Print the number of internship details found

# %%
#print(detail[0])

# %%
# Extract locations
location=[]
for i in detail:
  loc=i.find('a').text
  location.append(loc)
  #print(loc)
# print(len(location))
print(f"Locations are : {location}")
# Out:
# Locations are : ['Bangalore', 'Work from home', 'Delhi', 'Gurgaon', 'Work from home', 'Ahmedabad', 'Work from home', 'Work from home', 'Ahmedabad', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Indore, Jabalpur', 'Delhi', 'Work from home', 'Work from home', 'Chennai', 'Noida, Greater Noida, Delhi', 'Delhi', 'Work from home', 'Delhi', 'Work from home', 'Work from home', 'Work from home', 'Gurgaon', 'Work from home', 'Work from home', 'Mohali', 'Bangalore', 'Work from home', 'Mumbai, Ahmedabad, Navi Mumbai, Bangalore, Pune', 'Work from home', 'Work from home', 'Work from home', 'Bareilly, Udaipur', 'Work from home', 'Work from home', 'Dehradun', 'Chennai', 'Work from home', 'Bangalore', 'Work from home', 'Work from home', 'Work from home', 'Kolkata', 'Bangalore', 'Noida', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Bangalore', 'Work from home', 'Work from home', 'Bangalore', 'Work from home', 'Work from home', 'Work from home', 'Delhi', 'Bangalore, Koramangala', 'Sonipat', 'Hyderabad', 'Bangalore', 'Ahmedabad', 'Work from home', 'Work from home', 'Gurgaon', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Mandi', 'Bangalore', 'Work from home', 'Bangalore', 'Work from home', 'Delhi, Gurgaon', 'Work from home', 'Work from home', 'Ahmedabad', 'Mumbai', 'Faridabad', 'Work from home', 'Work from home', 'Thanjavur, Theni, Tiruchendur, Tiruppur, Pondicherry, Karaikudi, Pollachi, Kanyakumari, Madurai, Tirunelveli, Nagercoil, Erode, Karur, Coimbatore, Tenkasi', 'Sathyamangalam, Gobichettipalayam, Mettupalayam, Attur, Salem, Thoothukudi, Tiruchirappalli, Palakkad, Sivakasi, Tirunelveli, Virudhunagar, Tiruchengode, Coimbatore, Erode', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Delhi', 'Work from home', 'Work from home', 'Pune', 'Delhi', 'Work from home', 'Meerut', 'Work from home', 'Work from home', 'Delhi', 'Gurgaon', 'Chennai, Coimbatore, Madurai', 'Bangalore', 'Chennai, Coimbatore, Madurai', 'Work from home', 'Work from home', 'Chennai, Coimbatore, Madurai', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Mumbai', 'Work from home', 'Jaipur', 'Mumbai', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Delhi', 'Work from home', 'Delhi', 'Work from home', 'Indore', 'Ahmedabad', 'Bangalore', 'Work from home', 'Mumbai', 'Mumbai', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Work from home', 'Hyderabad', 'Bareilly', 'Kolkata', 'Delhi', 'Hyderabad', 'Work from home', 'Kolkata', 'Work from home', 'Work from home', 'Andhra Pradesh, Delhi, Indore, Chennai, Bhubaneswar, Bhopal, Bangalore, Hyderabad, Kolkata, Pune, Gwalior West, Noida, Raipur, Mumbai, Jaipur', 'Kolkata, Pune, Ahmedabad, Chennai, Jaipur, Himachal Pradesh, Munnar, Mumbai, Kochi, Bangalore, Bhopal', 'Work from home', 'Work from home', 'Work from home', 'Delhi', 'Work from home', 'Panaji', 'Delhi', 'Jaipur', 'Delhi, Ghaziabad, Noida', 'Work from home', 'Work from home', 'Delhi', 'Work from home', 'Kasaragod, Kozhikode, Pathanamthitta, Thiruvananthapuram, Thrissur, Malappuram, Alappuzha, Wayanad, Kollam, Kottayam, Idukki, Kochi, Ernakulam, Palakkad, Kannur', 'Work from home', 'Kolkata, Mumbai, Salem, Gujrat (Pakistan), Bangalore, Hyderabad, Namakkal, Tiruchirappalli, Madurai, Pune, Coimbatore, Delhi, Chennai', 'Kolkata', 'Work from home', 'Bhopal', 'Work from home', 'Work from home', 'Mumbai', 'Bangalore', 'Work from home', 'Jaipur', 'Kolkata', 'Work from home', 'Work from home', 'Mohali, Fatehgarh Sahib, Rupnagar, Panchkula, Kharar, Chandigarh', 'Ropar, Kurali, Mohali, Kharar', 'Mumbai', 'Ludhiana, Kharar, Kurali, Punjab, Mohali', 'Rajpura, Mohali, Chandigarh, Patiala, Rupnagar, Punjab', 'Rajpura, Mohali, Patiala, Ludhiana, Chandigarh, Punjab,  ...

# %% [markdown]
# > **` You have to find Duration for each individual company?`**

# %%
# Extract durations of internships
duration_detail1=[]
for soup in soup2:
  duraList=soup.find_all('div',class_='item_body')
  for i in duraList:
    duration_detail1.append(i)
duration=[]
i = 1
while i < len(duration_detail1):
  duration.append(duration_detail1[i].text.strip()[0])
  i +=3
# print(len(duration))
print(duration)
# Out:
# ['6', '2', '3', '6', '1', '1', '6', '3', '6', '4', '6', '6', '6', '3', '2', '2', '3', '5', '6', '3', '6', '3', '6', '1', '6', '2', '6', '3', '6', '3', '2', '3', '6', '6', '6', '2', '3', '6', '3', '2', '6', '3', '2', '2', '6', '6', '3', '3', '2', '6', '3', '2', '2', '6', '6', '6', '6', '6', '2', '6', '6', '3', '3', '2', '6', '3', '6', '2', '3', '6', '1', '3', '3', '6', '3', '6', '3', '6', '6', '4', '2', '1', '3', '2', '3', '6', '4', '4', '2', '1', '3', '3', '3', '6', '3', '6', '1', '3', '2', '1', '6', '6', '6', '3', '6', '6', '6', '4', '6', '3', '6', '3', '6', '6', '6', '3', '2', '6', '6', '3', '6', '6', '3', '3', '6', '6', '6', '6', '6', '4', '1', '6', '6', '2', '6', '3', '6', '3', '6', '6', '6', '4', '6', '1', '3', '3', '6', '3', '6', '6', '3', '3', '6', '2', '1', '1', '2', '3', '6', '3', '6', '6', '6', '2', '6', '4', '2', '3', '2', '4', '6', '3', '2', '2', '6', '2', '6', '2', '3', '3', '4', '6', '3', '6', '3', '2', '6', '6', '6', '3', '6', '6', '2', '4', '6', '6', '3', '6', '6', '3', '3', '4', '3', '6', '3', '1', '3', '3', '5', '3', '6', '3', '4', '3', '6', '2', '6', '6', '6', '6', '6', '2', '6', '6', '4', '1', '6', '3', '6', '4', '6', '3', '4', '3', '5', '6', '6', '3', '3', '3', '6', '2', '6', '6', '1', '1', '3', '3', '3', '3', '1', '3', '6', '6', '6', '3', '2', '2', '2', '4', '5', '3', '1', '6', '2', '3', '3', '4', '6', '6', '6']

# %%
# Extract job stipends
stipend=[]
for soup in soup2:
  stipList=soup.find_all('span',class_='stipend')
  for i in stipList:
    val=i.text
    stipend.append(val)
# print(len(stipend))
print(f"Stipend is : {stipend}")
# Out:
# Stipend is : ['₹ 30,000 /month', '₹ 1,000 /month', '₹ 3,000 /month', '₹ 10,000-12,000 /month', '₹ 20,000 /month', '₹ 4,000-6,000 /month', '₹ 2,500 /month +  Incentives', '₹ 10,000 /month +  Incentives', '₹ 3,000-5,000 /month', '₹ 2,000-5,000 /month', '₹ 5,000 /month', '₹ 3,000 /month +  Incentives', '₹ 3,000 /month +  Incentives', '₹ 5,000 /month', '₹ 11,000 /month', '₹ 10,000 /month +  Incentives', '₹ 3,500 /month', '₹ 5,000 /month +  Incentives', '₹ 2,000 /month', '₹ 15,000-20,000 /month', '₹ 6,000 /month', '₹ 10,000 /month', '₹ 15,000 /month', '₹ 4,500 /month', '₹ 2,500 /month +  Incentives', '₹ 10,000-12,000 /month', '₹ 5,000-7,000 /month', '₹ 8,000 /month', '₹ 8,000 /month', '₹ 15,000 /month', '₹ 7,500 /month', '₹ 6,000-12,000 /month', '₹ 5,000-10,000 /month', '₹ 5,000-9,000 /month', '₹ 5,000-10,000 /month', '₹ 3,000 /month', '₹ 15,000 /month', '₹ 5,000-15,000 /month', '₹ 5,000 /month', '₹ 35,000 /month', '₹ 5,000-12,000 /month', '₹ 10,000 /month', '₹ 5,000-10,000 /month', '₹ 5,000 /month', '₹ 5,500 /month', '₹ 10,000 /month', '₹ 10,000-20,000 /month', '₹ 2,000-3,000 /month', '₹ 10,000 /month', '₹ 10,000-15,000 /month', '₹ 4,000 /month', '₹ 3,000-5,000 /month', '₹ 7,000-10,000 /month', '₹ 40,000 /month', '₹ 10,000 /month', '₹ 8,000 /month', '₹ 5,000 /month', '₹ 15,000 /month', '₹ 10,000-15,000 /month', '₹ 6,000-10,000 /month', '₹ 20,000-30,000 /month', '₹ 3,000 /month', '₹ 15,000 /month', '₹ 10,000 /month', '₹ 5,000 /month +  Incentives', '₹ 10,000-12,000 /month', '₹ 3,500 /month', '₹ 6,000-10,000 /month', '₹ 10,000 /month', '₹ 10,000 /month', '₹ 5,000-7,000 /month', '₹ 20,000 /month', '₹ 3,000 /month', '₹ 2,500 /month +  Incentives', '₹ 20,000-25,000 /month', '₹ 10,000 /month', '₹ 10,000-20,000 /month', '₹ 6,000 /month +  Incentives', '₹ 30,000 /month', '₹ 1,500 /month', '₹ 7,000 /month', '₹ 3,000 /month', '₹ 12,500 /month', '₹ 5,000 /month', '₹ 10,000 /month +  Incentives', '₹ 8,000 /month', '₹ 2,500 /month', '₹ 8,000-15,000 /month', '₹ 3,000 /month', '₹ 3,000 /month', '₹ 12,500 /month', '₹ 8,000-12,500 /month', '₹ 12,500 /month', '₹ 40,000 /month', '₹ 5,000 /month', '₹ 300-1,000 /week', '₹ 7,000 /month', '₹ 5,000-10,000 /month', '₹ 18,000 /month', '₹ 10,000 /month', '₹ 2,000 /month', '₹ 15,000-20,000 /month', '₹ 8,000 /month', '₹ 5,000 /month', '₹ 4,500 /month', '₹ 8,000 /month', '₹ 10,000-12,000 /month', '₹ 30,000 /month', '₹ 3,000 /month +  Incentives', '₹ 10,000-20,000 /month', '₹ 3,000 /month +  Incentives', '₹ 12,500 /month', '₹ 12,500 /month', '₹ 3,000 /month +  Incentives', '₹ 2,000-5,000 /month', '₹ 12,500 /month', '₹ 2,000-3,000 /month', '₹ 8,000-10,000 /month', '₹ 8,000-10,000 /month', '₹ 5,000-15,000 /month', '₹ 8,000-10,000 /month', '₹ 6,000 /month', '₹ 5,000 /month', '₹ 10,000-18,000 /month', '₹ 10,000 /month', '₹ 10,000 /month', '₹ 10,000 /month', '₹ 10,000 /month', '₹ 6,000-8,000 /month', '₹ 10,000 /month', 'Unpaid', '₹ 15,000 /month', '₹ 7,000 /month', '₹ 3,000 /month', '₹ 15,000 /month', '₹ 20,000-30,000 /month', '₹ 7,000 /month', '₹ 10,000 /month', '₹ 5,000-10,000 /month', '₹ 10,000-15,000 /month', '₹ 6,000 /month', '₹ 5,000-12,000 /month', '₹ 10,000 /month', '₹ 5,000 /month', '₹ 8,000 /month', '₹ 2,000-10,000 /month', '₹ 10,000-15,000 /month', '₹ 2,000 /month', '₹ 4,000-8,000 /month', '₹ 10,000-12,000 /month', '₹ 9,000-14,000 /month', '₹ 10,000 /month', '₹ 2,000 /month', '₹ 20,000 /month', '₹ 20,000 /month', '₹ 15,000 /month', '₹ 18,000 /month', '₹ 10,000 /month', '₹ 5,000-10,000 /month', '₹ 10,000-15,000 /month', '₹ 8,000 /month', '₹ 15,000 /month', '₹ 10,000 /month', '₹ 10,000 /month', '₹ 13,000 /month', '₹ 10,000 /month', '₹ 10,000-14,000 /month', '₹ 7,000 /month', '₹ 2,000 /month', '₹ 5,000 /month', '₹ 2,000 /month +  Incentives', '₹ 10,000-12,000 /month', '₹ 10,000 /month', '₹ 2,000 /month', '₹ 5,000 /month', '₹ 3,000 /month', '₹ 5,000-8,000 /month', '₹ 13,500 /month', '₹ 30,000 /month', '₹ 5,000 /month', '₹ 3,000-8,000 /month', '₹ 10,000 /month', '₹ 5,000 /month', '₹ 7,000-12,000 /month', '₹ 7, ...

# %%
# Extract application links
cont=[]
for soup in soup2:
  coutList=soup.find_all('div',class_='cta_container')
  for i in coutList:
    cont.append(i)

# %%
# get Applications link
application_link=[]
for i in cont:
  anc=i.find('a')
  link=anc.get('href')
  #print(link)
  updated_link='https://internshala.com/'+link
  #print(updated_link)
  application_link.append(updated_link)
# print(len(application_link))
print(f"Application Link is : {application_link}")
# Out:
# Application Link is : ['https://internshala.com//internship/details/ruby-software-developer-internship-in-bangalore-at-peach1716528014', 'https://internshala.com//internship/details/work-from-home-java-development-internship-at-codtech-it-solutions-private-limited1716526980', 'https://internshala.com//internship/details/backend-development-internship-in-delhi-at-flint-merchandising-llp1716523425', 'https://internshala.com//internship/details/php-development-internship-in-gurgaon-at-dakshith-technologies1716496086', 'https://internshala.com//internship/details/work-from-home-part-time-web-development-internship-at-mentorboxx1716473507', 'https://internshala.com//internship/details/web-development-internship-in-ahmedabad-at-time-education1716469988', 'https://internshala.com//internship/details/work-from-home-part-time-nodejs-development-internship-at-across-the-globe-atg1716469585', 'https://internshala.com//internship/details/work-from-home-web-development-internship-at-digimindss1716463663', 'https://internshala.com//internship/details/reactjs-development-internship-in-ahmedabad-at-close-digit-llp1716463240', 'https://internshala.com//internship/details/work-from-home-part-time-wordpress-development-internship-at-dizigroww1716461909', 'https://internshala.com//internship/details/work-from-home-part-time-wordpress-developer-internship-at-the-learn-cloud1716457971', 'https://internshala.com//internship/details/work-from-home-front-end-development-internship-at-workoai1716457524', 'https://internshala.com//internship/details/work-from-home-backend-development-internship-at-workoai1716457504', 'https://internshala.com//internship/details/nodejs-development-internship-in-multiple-locations-at-wellfounded-it-solution-private-limited1716447855', 'https://internshala.com//internship/details/python-development-internship-in-delhi-at-bamigos1716455040', 'https://internshala.com//internship/details/work-from-home-part-time-chrome-extension-and-nextjs-development-internship-at-solocl1716454792', 'https://internshala.com//internship/details/work-from-home-python-developer-with-good-hands-on-api-development-flask-fastapi-internship-at-arthalab-solutions1716454200', 'https://internshala.com//internship/details/full-stack-development-internship-in-chennai-at-pisence-technologies-llp1716452494', 'https://internshala.com//internship/details/php-development-internship-in-multiple-locations-at-bytive-technologies-private-limited1716445252', 'https://internshala.com//internship/details/python-development-internship-in-delhi-at-indietoga1716450976', 'https://internshala.com//internship/details/work-from-home-php-development-wordpress-internship-at-chirpn-it-solutions1716448358', 'https://internshala.com//internship/details/front-end-development-internship-in-delhi-at-ocpl-tech-opulentia-cresco-private-limited1716447961', 'https://internshala.com//internship/details/work-from-home-flutter-development-internship-at-coding-junior1716447387', 'https://internshala.com//internship/details/work-from-home-wordpress-development-internship-at-evkhoj1716444732', 'https://internshala.com//internship/details/work-from-home-part-time-reactjs-development-internship-at-across-the-globe-atg1716443610', 'https://internshala.com//internship/details/python-development-internship-in-gurgaon-at-warewe-consultancy-private-limited1716441586', 'https://internshala.com//internship/details/work-from-home-wordpress-development-internship-at-blackcoffer1716400334', 'https://internshala.com//internship/details/work-from-home-part-time-web-development-internship-at-chatcells1716382418', 'https://internshala.com//internship/details/reactjs-development-internship-in-mohali-at-iwebcode1716373915', 'https://internshala.com//internship/details/wordpress-development-internship-in-bangalore-at-confluencr1716380554', 'https://internshala.com//internship/details/work-from-home-frontend-developer-intern-internship-at-quantazone-software-private-limited1716379979', 'https://internshala.co ...

# %%
# @title Default title text
# Create a DataFrame with the extracted data
dataTable = {
    'profile': profile,
    "company": company,
    "location": location,
    "stipend":stipend,
    "duration": duration,
    "application Link": application_link
    }

df = pd.DataFrame(dataTable)
#print(f"""{len(profile)} {len(company)} {len(location)} {len(duration)} {len(stipend)} {len(application_link)}""")

print(df.head())  # Print the first few rows of the DataFrame

# Save the DataFrame to a CSV file
df.to_csv('internshala_internships.csv', index=False)
print("DataFrame saved to 'internshala_internships.csv'")

# %% [markdown]
# **Remember : https://internshala.com/internships/analytics-internship/page-1/ and https://internshala.com/internships/analytics-internship/ both are same**

# %% [markdown]
# > Check Points
#
#
# # Find Duration of each individual internship
# # All the information u have got till now create a dataframe out of it using pandas
# # Save the dataframe in CSV
# # Create a general Code to fetch data from any number of page : 😉
